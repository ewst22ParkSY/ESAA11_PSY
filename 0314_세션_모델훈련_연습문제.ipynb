# %% [markdown]
# <a href="https://colab.research.google.com/github/ewst22ParkSY/ESAA11_PSY/blob/ESAA11_OB/0314_%EC%84%B8%EC%85%98_%EB%AA%A8%EB%8D%B8%ED%9B%88%EB%A0%A8_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **모델 훈련 연습 문제**
# ___
# - 출처 : 핸즈온 머신러닝 Ch04 연습문제 1, 5, 9, 10
# - 개념 문제의 경우 텍스트 셀을 추가하여 정답을 적어주세요.

# %% [markdown]
# ### **1. 수백만 개의 특성을 가진 훈련 세트에서는 어떤 선형 회귀 알고리즘을 사용할 수 있을까요?**
# ___
#
# 확률적 경사하강법, 미니배치 경사하강법.

# %% [markdown]
# ### **2. 배치 경사 하강법을 사용하고 에포크마다 검증 오차를 그래프로 나타내봤습니다. 검증 오차가 일정하게 상승되고 있다면 어떤 일이 일어나고 있는 걸까요? 이 문제를 어떻게 해결할 수 있나요?**
# ___
#
# 모델이 과대적합(overfitting)되어있을 경우 검증 오차가 일정하게 상승한다. 이 경우 학습률을 낮추거나, 조기종료, epoch 크기 변경을 통해 문제를 해결할 수 있다.

# %% [markdown]
# ### **3. 릿지 회귀를 사용했을 때 훈련 오차가 검증 오차가 거의 비슷하고 둘 다 높았습니다. 이 모델에는 높은 편향이 문제인가요, 아니면 높은 분산이 문제인가요? 규제 하이퍼파라미터 $\alpha$를 증가시켜야 할까요 아니면 줄여야 할까요?**
# ___
#
#
# 과소적합(편향이 높고 분산이 낮음)이 문제인 것이다.
#
# 편향이 높아서 모델 복잡도를 높이기 위해 alpha를 줄여야 함.

# %% [markdown]
# ### **4. 다음과 같이 사용해야 하는 이유는?**
# ___
# - 평범한 선형 회귀(즉, 아무런 규제가 없는 모델) 대신 릿지 회귀
# - 릿지 회귀 대신 라쏘 회귀
# - 라쏘 회귀 대신 엘라스틱넷
#
#
# ---
# - 과대적합을 감소시키기 위함
# - 릿지가 기본이 되지만, 쓰이는 특성이 몇개 뿐이라고 의심되면 라쏘나 엘라스틱 넷이 나음.
# - 특성 수가 훈련 샘플 수보다 많거나 특성 몇 개가 강하게 연관되어 있으면 라쏘보다는 엘라스틱넷 활용

# %% [markdown]
# ### **추가) 조기 종료를 사용한 배치 경사 하강법으로 iris 데이터를 활용해 소프트맥스 회귀를 구현해보세요(사이킷런은 사용하지 마세요)**
#
#
# ---

# %%
from sklearn.datasets import load_iris

iris = load_iris()

# %%
X = iris['data'][:,(2,3)]
y = iris['target']

# %% [markdown]
# 과정 간단히 설명
#
# 1. 모든 샘플에 편향 추가
# 2. 수동으로 train test split
# 3. 클래스 인덱스를 원핫 벡터로 변경
# 4. 훈련 세트와 테스트 세트의 타깃 클래스 확률을 담은 행렬 만들기
# 5. 소프트 맥스 함수 만들기
# ```python
# def softmax(logits):
#     exps = np.exp(logits)
#     exp_sums = np.sum(exps, axis=1, keepdims=True)
#     return exps / exp_sums
# ```
# 6. 입출력 개수 정하기
# 7. 비용함수와 그라디언트 공식 구현
#
# ```python
# eta = 0.01
# n_iterations = 5001
# m = len(X_train)
# epsilon = 1e-7
#
# Theta = np.random.randn(n_inputs, n_outputs)
#
# for iteration in range(n_iterations):
#     logits = X_train.dot(Theta)
#     Y_proba = softmax(logits)
#     if iteration % 500 == 0:
#         loss = -np.mean(np.sum(Y_train_one_hot * np.log(Y_proba + epsilon), axis=1))
#         print(iteration, loss)
#     error = Y_proba - Y_train_one_hot
#     gradients = 1/m * X_train.T.dot(error)
#     Theta = Theta - eta * gradients
# ```
